# %% [markdown]
# # Tree comparison

# %% [markdown]
# ## case_insensitiv: changed GZMA_Canis_lupus to GZMA_Canis_lupus_1

# %%
import os
from ete3 import Tree as ete_tree
import dendropy 
from dendropy import Tree as dendropy_tree
from dendropy.calculate import treecompare

from pycirclize import Circos
from io import StringIO
from Bio import Phylo
import csv
from pathlib import Path

# %% [markdown]
# # Parameter

# %%
converter = False

out_dir = str(os.getcwd())+"/out_dir/"
#work_dir = str(os.getcwd())
input = "./inputs/"


multiple_comparison = True

reference_tree = str(out_dir) + "KLK.newick"
t2 = str(out_dir) + "KLK_esm2_upgma_2_manhattan.newick"

# %% [markdown]
# # Comparison Metric

# %%
def get_comparison(t1, t2):
    
    print("Reference Tree: ",t1)
    print("Tree: ",t2+"\n")
    
    ### ETE
    tree1_ete = ete_tree(t1)
    tree2_ete = ete_tree(t2)

    rf, max_rf, common_leaves, parts_t1, parts_t2, discard_t1, discart_t2  = tree1_ete.robinson_foulds(tree2_ete,unrooted_trees=True)
    print("RF distance is %s over a total of %s" %(rf, max_rf))
    print("Partitions in tree2 that were not found in tree1:", len(parts_t1 - parts_t2))
    print("Partitions in tree1 that were not found in tree2:", len(parts_t2 - parts_t1))


    ### Dendropy
    tns = dendropy.TaxonNamespace()
    tree1 = dendropy_tree.get(path=t1,
            schema="newick",taxon_namespace=tns)#,case_sensitive_taxon_labels=True)
    tree2 = dendropy_tree.get(
            path=t2,
            schema="newick",taxon_namespace=tns)#,case_sensitive_taxon_labels=True)

    #!!!! Problem with reading case insensitive leaf nodes !!!!
    #changed GZMA_Canis_lupus to GZMA_Canis_lupus_1: case_insensitvity 

    tree1.encode_bipartitions()
    tree2.encode_bipartitions()

    print("euclidean_distance: "+str(treecompare.euclidean_distance(tree1, tree2)))
    print("symmetric_difference: "+str(treecompare.symmetric_difference(tree1, tree2)))
    print("false_positives_and_negatives: "+str(treecompare.false_positives_and_negatives(tree1, tree2)))
    print("robinson_foulds_distance: "+str(treecompare.robinson_foulds_distance(tree1, tree2)))

# %%
if multiple_comparison:

    pathlist = Path(out_dir).rglob('*.newick')
    for path in pathlist:
        path_in_str = str(path)
        print("\n")
        get_comparison(reference_tree, path_in_str)
else:
    get_comparison(reference_tree, t2)
# Out:
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_49_euclidean.newick
#
# RF distance is 800 over a total of 850
# Partitions in tree2 that were not found in tree1: 391
# Partitions in tree1 that were not found in tree2: 409
# euclidean_distance: 18.565771578458804
# symmetric_difference: 804
# false_positives_and_negatives: (410, 394)
# robinson_foulds_distance: 216.38796797100002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_encode_100_euclidean.newick
#
# RF distance is 786 over a total of 850
# Partitions in tree2 that were not found in tree1: 384
# Partitions in tree1 that were not found in tree2: 402
# euclidean_distance: 55.36103973298432
# symmetric_difference: 790
# false_positives_and_negatives: (403, 387)
# robinson_foulds_distance: 397.12737865100064
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_encode_100_manhattan.newick
#
# RF distance is 788 over a total of 850
# Partitions in tree2 that were not found in tree1: 385
# Partitions in tree1 that were not found in tree2: 403
# euclidean_distance: 499.60983120340154
# symmetric_difference: 792
# false_positives_and_negatives: (404, 388)
# robinson_foulds_distance: 3082.7623776110013
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_49_ts_ss.newick
#
# RF distance is 792 over a total of 850
# Partitions in tree2 that were not found in tree1: 387
# Partitions in tree1 that were not found in tree2: 405
# euclidean_distance: 15054.50493145256
# symmetric_difference: 796
# false_positives_and_negatives: (406, 390)
# robinson_foulds_distance: 19621.593814646996
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_499_ts_ss.newick
#
# RF distance is 802 over a total of 850
# Partitions in tree2 that were not found in tree1: 392
# Partitions in tree1 that were not found in tree2: 410
# euclidean_distance: 18577.73996711137
# symmetric_difference: 806
# false_positives_and_negatives: (411, 395)
# robinson_foulds_distance: 21658.957622821003
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_2_ts_ss.newick
#
# RF distance is 742 over a total of 850
# Partitions in tree2 that were not found in tree1: 362
# Partitions in tree1 that were not found in tree2: 380
# euclidean_distance: 8534.248003382778
# symmetric_difference: 746
# false_positives_and_negatives: (381, 365)
# robinson_foulds_distance: 14274.694341965
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_49_cosine.newick
#
# RF distance is 826 over a total of 850
# Partitions in tree2 that were not found in tree1: 404
# Partitions in tree1 that were not found in tree2: 422
# euclidean_distance: 4.881687086948797
# symmetric_difference: 830
# false_positives_and_negatives: (423, 407)
# robinson_foulds_distance: 113.90707485500009
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_49_manhattan.newick
#
# RF distance is 806 over a total of 850
# Partitions in tree2 that were not found in tree1: 394
# Partitions in tree1 that were not found in tree2: 412
# euclidean_distance: 155.5835559183971
# symmetric_difference: 810
# false_positives_and_negatives: (413, 397)
# robinson_foulds_distance: 1498.4095956710012
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_2_manhattan.newick
#
# RF distance is 740 over a total of 850
# Partitions in tree2 that were not found in tree1: 361
# Partitions in tree1 that were not found in tree2: 379
# euclidean_distance: 419.37295769414885
# symmetric_difference: 744
# false_positives_and_negatives: (380, 364)
# robinson_foulds_distance: 6685.712566231001
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_49_ts_ss.newick
#
# RF distance is 840 over a total of 850
# Partitions in tree2 that were not found in tree1: 411
# Partitions in tree1 that were not found in tree2: 429
# euclidean_distance: 6593.988313502481
# symmetric_difference: 844
# false_positives_and_negatives: (430, 414)
# robinson_foulds_distance: 20938.358208186997
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_499_euclidean.newick
#
# RF distance is 818 over a total of 850
# Partitions in tree2 that were not found in tree1: 400
# Partitions in tree1 that were not found in tree2: 418
# euclidean_distance: 19.638827871229022
# symmetric_difference: 822
# false_positives_and_negatives: (419, 403)
# robinson_foulds_distance: 192.07957467300005
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_499_manhattan.newick
#
# RF distance is 818 over a total of 850
# Partitions in tree2 that were not found in tree1: 400
# Partitions in tree1 that were not found in tree2: 418
# euclidean_distance: 160.01617084533606
# symmetric_difference: 822
# false_positives_and_negatives: (419, 403)
# robinson_foulds_distance: 975.0544202909996
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_2_euclidean.newick
#
# RF distance is 746 over a total of 850
# Partitions in tree2 that were not found in tree1: 364
# Partitions in tree1 that were not found in tree2: 382
# euclidean_distance: 50.628741832807044
# symmetric_difference: 750
# false_positives_and_negatives: (383, 367)
# robinson_foulds_distance: 879.6777164909996
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_49_cosine.newick
#
# RF distance is 764 over a total of 850
# Partitions in tree2 that were not found in tree1: 373
# Partitions in tree1 that were not found in tree2: 391
# euclidean_distance: 4.930976399073559
# symmetric_difference: 768
# false_positives_and_negatives: (392, 376)
# robinson_foulds_distance: 115.29303992900002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_499_ts_ss.newick
#
# RF distance is 846 over a total of 850
# Partitions in tree2 that were not found in tree1: 414
# Partitions in tree1 that were not found in tree2: 432
# euclidean_distance: 7044.634540921687
# symmetric_difference: 850
# false_positives_and_negatives: (433, 417)
# robinson_foulds_distance: 22859.124415398997
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_2_manhattan.newick
#
# RF distance is 764 over a total of 850
# Partitions in tree2 that were not found in tree1: 373
# Partitions in tree1 that were not found in tree2: 391
# euclidean_distance: 166.17461058311238
# symmetric_difference: 768
# false_positives_and_negatives: (392, 376)
# robinson_foulds_distance: 3097.8471136710014
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_499_cosine.newick
#
# RF distance is 832 over a total of 850
# Partitions in tree2 that were not found in tree1: 407
# Partitions in tree1 that were not found in tree2: 425
# euclidean_distance: 4.912721016384333
# symmetric_difference: 836
# false_positives_and_negatives: (426, 410)
# robinson_foulds_distance: 113.13983490100013
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_49_euclidean.newick
# RF distance is 782 over a total of 850
# Partitions in tree2 that were not found in tree1: 382
# Partitions in tree1 that were not found in tree2: 400
# euclidean_distance: 53.92228612815037
# symmetric_difference: 786
# false_positives_and_negatives: (401, 385)
# robinson_foulds_distance: 478.2987771710002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_499_euclidean.newick
#
# RF distance is 802 over a total of 850
# Partitions in tree2 that were not found in tree1: 392
# Partitions in tree1 that were not found in tree2: 410
# euclidean_distance: 57.164355504582154
# symmetric_difference: 806
# false_positives_and_negatives: (411, 395)
# robinson_foulds_distance: 375.1392162509994
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_499_manhattan.newick
#
# RF distance is 802 over a total of 850
# Partitions in tree2 that were not found in tree1: 392
# Partitions in tree1 that were not found in tree2: 410
# euclidean_distance: 530.9195931693863
# symmetric_difference: 806
# false_positives_and_negatives: (411, 395)
# robinson_foulds_distance: 2737.4873488509998
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_49_manhattan.newick
#
# RF distance is 786 over a total of 850
# Partitions in tree2 that were not found in tree1: 384
# Partitions in tree1 that were not found in tree2: 402
# euclidean_distance: 488.69369600442667
# symmetric_difference: 790
# false_positives_and_negatives: (403, 387)
# robinson_foulds_distance: 3786.694672210999
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_2_cosine.newick
#
# RF distance is 742 over a total of 850
# Partitions in tree2 that were not found in tree1: 362
# Partitions in tree1 that were not found in tree2: 380
# euclidean_distance: 4.621150108828241
# symmetric_difference: 746
# false_positives_and_negatives: (381, 365)
# robinson_foulds_distance: 112.6754906510002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_encode_100_cosine.newick
#
# RF distance is 770 over a total of 850
# Partitions in tree2 that were not found in tree1: 376
# Partitions in tree1 that were not found in tree2: 394
# euclidean_distance: 4.973852646393139
# symmetric_difference: 774
# false_positives_and_negatives: (395, 379)
# robinson_foulds_distance: 115.26026720699987
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
#
# RF distance is 0 over a total of 834
# Partitions in tree2 that were not found in tree1: 0
# Partitions in tree1 that were not found in tree2: 0
# euclidean_distance: 0.0
# symmetric_difference: 0
# false_positives_and_negatives: (0, 0)
# robinson_foulds_distance: 0.0
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_encode_100_ts_ss.newick
#
# RF distance is 802 over a total of 850
# Partitions in tree2 that were not found in tree1: 392
# Partitions in tree1 that were not found in tree2: 410
# euclidean_distance: 17119.68269691083
# symmetric_difference: 806
# false_positives_and_negatives: (411, 395)
# robinson_foulds_distance: 20743.488243161002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_2_euclidean.newick
#
# RF distance is 756 over a total of 850
# Partitions in tree2 that were not found in tree1: 369
# Partitions in tree1 that were not found in tree2: 387
# euclidean_distance: 20.7385012641853
# symmetric_difference: 760
# false_positives_and_negatives: (388, 372)
# robinson_foulds_distance: 397.7760827109998
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_upgma_499_cosine.newick
#
# RF distance is 782 over a total of 850
# Partitions in tree2 that were not found in tree1: 382
# Partitions in tree1 that were not found in tree2: 400
# euclidean_distance: 5.02489224073134
# symmetric_difference: 786
# false_positives_and_negatives: (401, 385)
# robinson_foulds_distance: 114.71747431499992
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_2_cosine.newick
#
# RF distance is 780 over a total of 850
# Partitions in tree2 that were not found in tree1: 381
# Partitions in tree1 that were not found in tree2: 399
# euclidean_distance: 4.719909174227773
# symmetric_difference: 784
# false_positives_and_negatives: (400, 384)
# robinson_foulds_distance: 112.3884816890002
#
#
# Reference Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK.newick
# Tree:  /Users/adel.schmucklermann/Desktop/PyTorch_Lightning_VAE/out_dir/KLK_esm2_nj_2_ts_ss.newick
#
# RF distance is 832 over a total of 850
# Partitions in tree2 that were not found in tree1: 407
# Partitions in tree1 that were not found in tree2: 425
# euclidean_distance: 4059.4106657009875
# symmetric_difference: 836
# false_positives_and_negatives: (426, 410)
# robinson_foulds_distance: 15862.818536515008

# %% [markdown]
# # Draw Tree with Circos

# %%
tree_in = t2

#read color_file
dict_color = {}
with open(str(input) + "KLK_iTOL.txt") as csv_file:
    for row in csv.reader(csv_file, delimiter='\t'):
        if len(row) > 1:
            key = row[2]
            if key in dict_color:
                dict_color[key].append(row[0])
            else:
                dict_color[key] = [row[0]]
                
list_of_color = [(value,key) for key, value in dict_color.items()]                                    


#create tree
tree = Phylo.read(tree_in, "newick")

# Initialize circos sector with tree size
circos = Circos(sectors={"Tree": tree.count_terminals()})
sector = circos.sectors[0]

# Plot tree
track = sector.add_track((50, 100))
track.tree(tree,leaf_label_size=4, node_color_list=list_of_color)

fig = circos.plotfig()
#circos.savefig(str(out_dir) + "KLK_prott5.png", dpi=300)

# %% [markdown]
# # Format change

# %% [markdown]
# ## Convert h5 to npz

# %%
if converter: 

    h5_file = str(input) + "KLK_prott5.h5"
    prott5 = True

    #make numpy file with (seq header, embedding)
    esm2 = h5py.File(h5_file, 'r')
    list(esm2.keys())
    # List all groups
    keys = list(esm2.keys())
    #print(keys) 
    # Get the data
    esm2values = []
    headers = []
    for key in keys:
        #data
        emb = esm2[key][:]
        #value = np.array(esm2[key][:])
        #print(value)
        if prott5:
            esm2values.append(emb[0])
        else:    
            esm2values.append(emb)
        #headers
        key = key.replace("isoform=", "isoform_").replace("=", "").replace(":", "_")

        #check case-sensitivity
        if key.lower() in (item.lower() for item in headers):
            print('The string is in list: '+key)
            key = key+"_01"
            print('New key: '+key)

        headers.append(key)

    #np.savez("/Users/adel.schmucklermann/Desktop/FoPra/KLK/KLK_prott5.npz", headers=headers, embedding=esm2values)

# %% [markdown]
# ## Convert Nexus to Newick

# %%
if converter:
    import dendropy
    post_trees = dendropy.TreeList()
    post_trees.read(
             file=open(str(out_dir) + "KLK.nexus", "r"),
             schema="nexus")
    post_trees.write(
         path=str(out_dir) + "KLK.newick",schema="newick")

    #changed GZMA_Canis_lupus to GZMA_Canis_lupus_1: case_insensitvity
